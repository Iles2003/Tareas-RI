# %% [markdown]
# # Stiven Saldaña

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/pagina/allrecipes.com_million-dollar-soup-recipe-11823470.html
# /kaggle/input/receta2/www.allrecipes.com_chicken-cobbler-recipe-7966464.html

# %% [markdown]
# # Ejercicio 11: Web Scraping
# ## Objetivo de la práctica
# El objetivo de este ejercicio es construir un web scraper que recoja datos de un website.
#
# ## Parte 0: Planificar
# 1. Identificar los datos que quieres obtener.
# 2. Elegir el sitio web objetivo.
# 3. Planificar la estructura del corpus.
#
# ## Parte 1: Entender el sitio web objetivo
# * Analizar la estructura de la página web a ser analizada.
# * Identificar los elementos HTML que contienen los datos bsuscados.

# %%
from bs4 import BeautifulSoup
import os 
file_path = '/kaggle/input/pagina/allrecipes.com_million-dollar-soup-recipe-11823470.html'
with open(file_path, 'r', encoding='utf-8') as file:
    content = file.read()

soup = BeautifulSoup(content, 'html.parser')

# %%
title = soup.find("meta", {"property": "og:title"})["content"]
title
# Out:
# 'Million Dollar Soup'

# %%
ingredients_section = soup.find_all("li", class_="mm-recipes-structured-ingredients__list-item")
for ingredient in ingredients_section:
    print(ingredient.text.strip())
# Out:
# 2 tablespoons butter
# 1/2 onion, chopped
# 2 stalks celery, chopped
# salt and freshly ground black pepper to taste
# 2 cups diced Yukon Gold potatoes
# 1 can condensed cream of chicken soup
# 1 can Cheddar cheese soup
# 4 cups chicken broth
# 1 tablespoon Cajun seasoning
# 1 teaspoon garlic powder
# 1 teaspoon onion powder
# 4 cups chopped rotisserie chicken, or more to taste
# 5 strips bacon, cooked and chopped
# 1/2 cup sour cream
# 1/2 cup shredded creamy mozzarella cheese
# 1/4 cup shredded Cheddar cheese
# cooked and crumbled bacon
# scallions, sliced
# buttery round crackers, such as Ritz®, crushed

# %% [markdown]
# # Parte 2: Obtener los datos deseados
# * Buscar dentro del contenido HTML y extraer la información.

# %%
score=soup.find("div", {"id":"mm-recipes-review-bar__rating_1-0"})
score.string
# Out:
# '4.4'

# %%
preptime=soup.find("div", {"class":"mm-recipes-details__value"})
preptime.string
# Out:
# '15 mins'

# %%
description=soup.find("p", {"class":"article-subheading text-utility-300"})
description.string
# Out:
# 'This milion dollar soup is creamy, cheesy, rich, and savory, and yet uses convenient rotisserie chicken, and easy canned soups to create the base. Garnish with crushed Ritz crackers, sliced green onion, crumbled bacon, and Cheddar cheese, and yes, you will feel like you have stumbled into a fortune.'

# %%
# Extracting the description
description = soup.find("meta", {"name": "description"})["content"]

# Extracting the ingredients
ingredients_section = soup.find_all("li", class_="mm-recipes-structured-ingredients__list-item")
ingredients = [ingredient.get_text().strip() for ingredient in ingredients_section]

# Extracting the instructions
instructions_section = soup.find_all("p", class_="comp mntl-sc-block mntl-sc-block-html")
instructions = [instruction.get_text().strip() for instruction in instructions_section]

# Extracting the nutrition information
nutrition_section = soup.find_all("span", class_="mm-recipes-nutrition-facts-label__nutrient-name mm-recipes-nutrition-facts-label__nutrient-name--has-postfix")
nutrition_facts = [fact.parent.get_text().strip().replace('\n', ' ') for fact in nutrition_section]

# Print the extracted information
print("Recipe Title:", title)
print("Description:", description)
print("Ingredients:")
for ingredient in ingredients:
    print("-", ingredient)
print("Instructions:")
for i, instruction in enumerate(instructions, 1):
    print(f"{i}. {instruction}")
print("Nutrition Facts:")
for fact in nutrition_facts:
    print("-", fact)
# Out:
# Recipe Title: Million Dollar Soup
# Description: This milion dollar soup is creamy, cheesy, rich, and savory, and yet uses convenient rotisserie chicken, and easy canned soups to create the base. Garnish with crushed Ritz crackers, sliced green onion, crumbled bacon, and Cheddar cheese, and yes, you will feel like you have stumbled into a fortune.
# Ingredients:
# - 2 tablespoons butter
# - 1/2 onion, chopped
# - 2 stalks celery, chopped
# - salt and freshly ground black pepper to taste
# - 2 cups diced Yukon Gold potatoes
# - 1 can condensed cream of chicken soup
# - 1 can Cheddar cheese soup
# - 4 cups chicken broth
# - 1 tablespoon Cajun seasoning
# - 1 teaspoon garlic powder
# - 1 teaspoon onion powder
# - 4 cups chopped rotisserie chicken, or more to taste
# - 5 strips bacon, cooked and chopped
# - 1/2 cup sour cream
# - 1/2 cup shredded creamy mozzarella cheese
# - 1/4 cup shredded Cheddar cheese
# - cooked and crumbled bacon
# - scallions, sliced
# - buttery round crackers, such as Ritz®, crushed
# Instructions:
# 1. Melt 2 tablespoons butter in a large pot over medium heat. Add onions and celery and cook until tender, 4 to 5 minutes. Season with salt and pepper.
# 2. Add potatoes, cream of chicken, Cheddar cheese soup, and broth to the pot and season with Cajun seasoning, garlic powder, and onion powder. Simmer for 5 minutes. Add chicken and bacon to the soup.
# 3. Reduce heat to low, and simmer, stirring occasionally, 15 to 20 minutes more. Stir in sour cream and creamy mozzarella; remove from heat.
# 4. Serve garnished with shredded Cheddar, bacon, scallions, and crushed Ritz crackers.
# Nutrition Facts:
# - Total Fat 25g
# - Saturated Fat 10g
# - Cholesterol 148mg
# - Sodium 1333mg
# - Total Carbohydrate 17g
# - Dietary Fiber 1g
# - Total Sugars 2g
# - Protein 33g
# - Vitamin C 4mg
# - Calcium 147mg
# - Iron 2mg
# - Potassium 703mg

# %% [markdown]
# # Parte 3: Obtener enlaces relacionados
# * Encontrar links a otras recetas para completar el corpus

# %%
# Find all the links to other recipes
recipe_links = soup.find_all("a", href=True)

# Filter and print only the links that are likely to be recipes
recipe_urls = []
for link in recipe_links:
    href = link['href']
    if "recipe" in href:
        recipe_urls.append(href)

# Print the recipe URLs
print("Linked Recipes:")
for url in recipe_urls:
    print(url)
# Out:
# Linked Recipes:
# https://www.allrecipes.com/authentication/login?regSource=3675&relativeRedirectUrl=%2Fmillion-dollar-soup-recipe-11823470
# /account/add-recipe
# https://www.myrecipes.com/favorites
# https://support.people.inc/hc/en-us/categories/360003648613-Allrecipes
# https://www.allrecipes.com/authentication/logout?relativeRedirectUrl=%2Fmillion-dollar-soup-recipe-11823470
# https://www.allrecipes.com/food-news-trends/
# https://www.allrecipes.com/recipes/1642/everyday-cooking/
# https://www.allrecipes.com/kitchen-tips/how-to/dinner-fix/
# https://www.allrecipes.com/kitchen-tips/how-to/sweet-spot/
# https://www.allrecipes.com/kitchen-tips/in-the-kitchen/
# https://www.allrecipes.com/video
# https://www.allrecipes.com/allstars-8661275
# https://www.allrecipes.com/article/how-to-submit-recipes/
# https://www.myrecipes.com/authentication/login?regSource=z5qeew&isMyrecipes=true&utm_source=allrecipes&utm_medium=sitewidebanner
# https://www.allrecipes.com/recipes/
# https://www.allrecipes.com/recipes/94/soups-stews-and-chili/
# https://www.allrecipes.com/recipes/16369/soups-stews-and-chili/soup/
# https://www.allrecipes.com/recipes/1246/soups-stews-and-chili/soup/chicken-soup/
# https://www.allrecipes.com/natalie-gravois-11693443
# https://www.allrecipes.com/natalie-gravois-11693443
# https://www.allrecipes.com/allrecipes-test-kitchen-7553892
# https://www.allrecipes.com/allrecipes-test-kitchen-7553892
# /about-allrecipes-test-kitchen-7550983
# https://www.allrecipes.com/recipe/272232/chicken-potato-soup/
# https://www.allrecipes.com/recipe/13404/worlds-best-potato-soup/
# https://www.allrecipes.com/recipe/13218/absolutely-ultimate-potato-soup/
# https://www.allrecipes.com/recipe/25665/baked-potato-soup-v/
# https://www.allrecipes.com/recipe/277943/slow-cooker-loaded-potato-soup/
# https://www.allrecipes.com/recipe/18449/cream-of-chicken-and-potato-soup/
# https://www.allrecipes.com/recipe/256745/hash-brown-potato-soup/
# https://www.allrecipes.com/recipe/235445/very-easy-potato-bacon-soup/
# https://www.allrecipes.com/recipe/22927/creamy-potato-leek-soup-ii/
# https://www.allrecipes.com/recipe/282332/potato-soup-with-hash-browns/
# https://www.allrecipes.com/recipe/280812/instant-pot-frozen-potato-soup/
# https://www.allrecipes.com/recipe/277373/slow-cooker-potato-bacon-soup/
# https://www.allrecipes.com/recipe/259798/slow-cooker-loaded-baked-potato-soup/
# https://www.allrecipes.com/recipe/245233/garlic-soup-with-crispy-prosciutto/
# https://www.allrecipes.com/recipe/215099/creamy-green-bean-and-potato-soup/
# https://www.allrecipes.com/recipe/13291/ians-potato-vegetable-soup/
# https://www.facebook.com/allrecipes
# https://www.instagram.com/allrecipes/
# https://www.pinterest.com/allrecipes/
# https://www.tiktok.com/@allrecipes
# https://www.youtube.com/user/allrecipes/videos
# https://flipboard.com/@Allrecipes
# https://www.allrecipes.com/recipes/17562/dinner/
# https://www.allrecipes.com/recipes/
# https://www.allrecipes.com/recipes/17567/ingredients/
# https://www.allrecipes.com/recipes/85/holidays-and-events/
# https://www.allrecipes.com/recipes/86/world-cuisine/
# https://www.allrecipes.com/kitchen-tips/
# https://www.allrecipes.com/food-news-trends/
# https://www.allrecipes.com/recipes/1642/everyday-cooking/
# https://www.allrecipes.com/video
# https://www.people.inc/brands/food-drink/allrecipes

# %% [markdown]
# # Parte 4: Hacer RAG con las recetas obtenidas
# * Una vez que se ha construido el corpus, implementar y desplegar RAG para realizar búsquedas en el corpus

# %%
# !pip install -q langchain langchain-community faiss-cpu sentence-transformers transformers accelerate

# %%
import requests
from bs4 import BeautifulSoup
from langchain.docstore.document import Document
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import FAISS
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_community.llms import HuggingFacePipeline
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM, pipeline
from langchain.chains import RetrievalQA
from langchain.prompts import PromptTemplate

# se cargan los URL
cleaned_urls = []
seen = set()

for url in recipe_urls:
    full_url = url if url.startswith('http') else f"https://www.allrecipes.com{url}"
    if "/recipe/" in full_url and \
       not any(x in full_url for x in ["login", "logout", "account", "video", "gallery"]) and \
       full_url not in seen:
        
        cleaned_urls.append(full_url)
        seen.add(full_url)

target_urls = cleaned_urls[:16]
def scrape_recipe_content(url):
    try:
        headers = {'User-Agent': 'Mozilla/5.0'}
        response = requests.get(url, headers=headers, timeout=10)
        if response.status_code != 200: return None
        soup = BeautifulSoup(response.content, "html.parser")
        title_tag = soup.find("h1")
        title = title_tag.get_text().strip() if title_tag else "Receta"
        ingredients = [li.get_text().strip() for li in soup.find_all("li", class_="mm-recipes-structured-ingredients__list-item")]
        instructions = [p.get_text().strip() for p in soup.find_all("p", class_="comp mntl-sc-block mntl-sc-block-html")]
        if not ingredients: return None
        return f"RECIPE: {title}\nINGREDIENTS: {', '.join(ingredients)}\nINSTRUCTIONS: {' '.join(instructions)}", url
    except:
        return None

documents = []
for url in target_urls:
    data = scrape_recipe_content(url)
    if data:
        documents.append(Document(page_content=data[0], metadata={"source": data[1]}))

if not documents:
    raise ValueError("Error")

# vectorizacion
text_splitter = RecursiveCharacterTextSplitter(chunk_size=800, chunk_overlap=100)
splits = text_splitter.split_documents(documents)
embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")
vectorstore = FAISS.from_documents(splits, embeddings)

# se carga el modelo
model_id = "google/flan-t5-large"
tokenizer = AutoTokenizer.from_pretrained(model_id)
model = AutoModelForSeq2SeqLM.from_pretrained(model_id)

pipe = pipeline(
    "text2text-generation", 
    model=model, 
    tokenizer=tokenizer, 
    max_length=512,
    temperature=0.1
)
local_llm = HuggingFacePipeline(pipeline=pipe)



# promt para la busqueda
template = """Use the following context to answer the question at the end. 
If the answer is not in the context, say "I don't know".

Context: 
{context}

Question: 
{question}

Answer:"""

QA_CHAIN_PROMPT = PromptTemplate.from_template(template)

qa_chain = RetrievalQA.from_chain_type(
    llm=local_llm,
    chain_type="stuff",
    retriever=vectorstore.as_retriever(search_kwargs={"k": 2}),
    chain_type_kwargs={"prompt": QA_CHAIN_PROMPT},
    return_source_documents=True
)
# Out:
# Device set to use cuda:0

# %%
# se define una pregunta como query
query = "What ingredients do i need to make baked chicken??"
print(f"Buscando: {query}")
result = qa_chain.invoke({"query": query})

# respuesta
print("\n Respuesta:")
print(result['result'])
# Out:
# Buscando: What ingredients do i need to make baked chicken??
#
#  Respuesta:
# butter, all-purpose flour, onion, fresh chives, heavy cream, milk, water, ground cumin, salt, ground black pepper, garlic powder, thyme, potatoes, peeled and cubed, skinless, boneless chicken breast halves - cut into cubes, fresh parsley
